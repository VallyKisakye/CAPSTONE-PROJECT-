# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import math
import time 
import datetime
import operator
plt.style.use("seaborn")
# %matplotlib inline

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\D1 TELECOM LTD\\Desktop\\vally\\MASTERS IN BIG DATA ANALYSIS'

# %%
os.chdir('C:\\Users\\D1 TELECOM LTD\\Desktop\\vally\\MASTERS IN BIG DATA ANALYSIS')
os.getcwd()
# Out:
# 'C:\\Users\\D1 TELECOM LTD\\Desktop\\vally\\MASTERS IN BIG DATA ANALYSIS'

# %%
# loading the data set
df = pd.read_csv('WHO _ COVID-19 .csv')
df.head()
# Out:
#                        Name       WHO Region  Cases - cumulative total  \
# 0                    Global              NaN                 200174883
# 1  United States of America         Americas                  35125227
# 2                     India  South-East Asia                  31812114
# 3                    Brazil         Americas                  19985817
# 4        Russian Federation           Europe                   6379904
#
#    Cases - cumulative total per 100000 population  \
# 0                                     2568.142235
# 1                                    10611.770000
# 2                                     2305.220000
# 3                                     9402.460000
# 4                                     4371.760000
#
#    Cases - newly reported in last 7 days  \
# 0                                4219657
# 1                                 651439
# 2                                 284000
# 3                                 236744
# ...

# %%
df.shape
# Out:
# (238, 12)

# %%
df.columns
# Out:
# Index(['Name', 'WHO Region', 'Cases - cumulative total',
#        'Cases - cumulative total per 100000 population',
#        'Cases - newly reported in last 7 days',
#        'Cases - newly reported in last 7 days per 100000 population',
#        'Cases - newly reported in last 24 hours', 'Deaths - cumulative total',
#        'Deaths - cumulative total per 100000 population',
#        'Deaths - newly reported in last 7 days',
#        'Deaths - newly reported in last 7 days per 100000 population',
#        'Deaths - newly reported in last 24 hours'],
#       dtype='object')

# %%
df.loc[1, :]
# Out:
# Name                                                            United States of America
# WHO Region                                                                      Americas
# Cases - cumulative total                                                        35125227
# Cases - cumulative total per 100000 population                                   10611.8
# Cases - newly reported in last 7 days                                             651439
# Cases - newly reported in last 7 days per 100000 population                       196.81
# Cases - newly reported in last 24 hours                                           114820
# Deaths - cumulative total                                                         609613
# Deaths - cumulative total per 100000 population                                   184.17
# Deaths - newly reported in last 7 days                                              2927
# ...

# %%
#using the list of labels to specify the list of rows
df.loc[[1], :]
# Out:
#                        Name WHO Region  Cases - cumulative total  \
# 1  United States of America   Americas                  35125227
#
#    Cases - cumulative total per 100000 population  \
# 1                                        10611.77
#
#    Cases - newly reported in last 7 days  \
# 1                                 651439
#
#    Cases - newly reported in last 7 days per 100000 population  \
# 1                                             196.81
#
#    Cases - newly reported in last 24 hours  Deaths - cumulative total  \
# 1                                   114820                     609613
#
#    Deaths - cumulative total per 100000 population  \
# 1                                           184.17
#
#    Deaths - newly reported in last 7 days  \
# 1                                    2927
#
#    Deaths - newly reported in last 7 days per 100000 population  \
# 1                                               0.88
#
#    Deaths - newly reported in last 24 hours
# ...

# %%
df.describe()
# Out:
#        Cases - cumulative total  \
# count              2.380000e+02
# mean               1.682142e+06
# std                1.337386e+07
# min                0.000000e+00
# 25%                5.068000e+03
# 50%                5.390850e+04
# 75%                3.901368e+05
# max                2.001749e+08
#
#        Cases - cumulative total per 100000 population  \
# count                                      237.000000
# mean                                      3926.470178
# std                                       4240.079182
# min                                          0.000000
# 25%                                        283.210000
# 50%                                       2447.820000
# 75%                                       6903.670000
# max                                      19150.970000
#
#        Cases - newly reported in last 7 days  \
# count                           2.380000e+02
# mean                            3.545930e+04
# ...

# %%
df.isnull().sum()
# Out:
# Name                                                            0
# WHO Region                                                      1
# Cases - cumulative total                                        0
# Cases - cumulative total per 100000 population                  1
# Cases - newly reported in last 7 days                           0
# Cases - newly reported in last 7 days per 100000 population     1
# Cases - newly reported in last 24 hours                         0
# Deaths - cumulative total                                       0
# Deaths - cumulative total per 100000 population                 1
# Deaths - newly reported in last 7 days                          0
# Deaths - newly reported in last 7 days per 100000 population    1
# Deaths - newly reported in last 24 hours                        0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

plt.figure(figsize=(20,10))
df["WHO Region"].value_counts().plot.pie(autopct='%1.1f%%',)
# Out:
# <AxesSubplot:ylabel='WHO Region'>

# %%
df['WHO Region'].value_counts().to_frame()
# Out:
#                        WHO Region
# Europe                         62
# Americas                       56
# Africa                         50
# Western Pacific                35
# Eastern Mediterranean          22
# South-East Asia                11
# Other                           1

# %%
df=df[df["WHO Region"]=="Americas"]
df.head()
# Out:
#                         Name WHO Region  Cases - cumulative total  \
# 1   United States of America   Americas                  35125227
# 3                     Brazil   Americas                  19985817
# 8                  Argentina   Americas                   4961880
# 9                   Colombia   Americas                   4807979
# 16                    Mexico   Americas                   2880409
#
#     Cases - cumulative total per 100000 population  \
# 1                                         10611.77
# 3                                          9402.46
# 8                                         10978.64
# 9                                          9449.11
# 16                                         2234.04
#
#     Cases - newly reported in last 7 days  \
# 1                                  651439
# 3                                  236744
# 8                                   85953
# 9                                   60204
# ...

# %%
df.tail()
# Out:
#                             Name WHO Region  Cases - cumulative total  \
# 214  Falkland Islands (Malvinas)   Americas                        63
# 215    Saint Pierre and Miquelon   Americas                        28
# 217                   Montserrat   Americas                        21
# 218               Sint Eustatius   Americas                        20
# 220                         Saba   Americas                         8
#
#      Cases - cumulative total per 100000 population  \
# 214                                         1808.79
# 215                                          483.18
# 217                                          420.08
# 218                                          637.15
# 220                                          413.86
#
#      Cases - newly reported in last 7 days  \
# 214                                      3
# 215                                      0
# 217                                      0
# 218                                      0
# ...

# %%
os.chdir("C:\\Users\\D1 TELECOM LTD\\Desktop\\vally\\MASTERS IN BIG DATA ANALYSIS")
os.getcwd()
# Out:
# 'C:\\Users\\D1 TELECOM LTD\\Desktop\\vally\\MASTERS IN BIG DATA ANALYSIS'

# %%
# loading the americas data set
df2 = pd.read_csv('american new.csv')
df2.head()
# Out:
#                        Name WHO Region  Cases - cumulative total  \
# 0  United States of America   Americas                  35125227
# 1                    Brazil   Americas                  19985817
# 2                 Argentina   Americas                   4961880
# 3                  Colombia   Americas                   4807979
# 4                    Mexico   Americas                   2880409
#
#    Cases - cumulative total per 100000 population  \
# 0                                        10611.77
# 1                                         9402.46
# 2                                        10978.64
# 3                                         9449.11
# 4                                         2234.04
#
#    Cases - newly reported in last 7 days  \
# 0                                 651439
# 1                                 236744
# 2                                  85953
# 3                                  60204
# 4                                 108563
#
# ...

# %%
df2.tail()
# Out:
#                            Name WHO Region  Cases - cumulative total  \
# 51  Falkland Islands (Malvinas)   Americas                        63
# 52    Saint Pierre and Miquelon   Americas                        28
# 53                   Montserrat   Americas                        21
# 54               Sint Eustatius   Americas                        20
# 55                         Saba   Americas                         8
#
#     Cases - cumulative total per 100000 population  \
# 51                                         1808.79
# 52                                          483.18
# 53                                          420.08
# 54                                          637.15
# 55                                          413.86
#
#     Cases - newly reported in last 7 days  \
# 51                                      3
# 52                                      0
# 53                                      0
# 54                                      0
# ...

# %%
df2.shape
# Out:
# (56, 12)

# %%
df2.columns
# Out:
# Index(['Name', 'WHO Region', 'Cases - cumulative total',
#        'Cases - cumulative total per 100000 population',
#        'Cases - newly reported in last 7 days',
#        'Cases - newly reported in last 7 days per 100000 population',
#        'Cases - newly reported in last 24 hours', 'Deaths - cumulative total',
#        'Deaths - cumulative total per 100000 population',
#        'Deaths - newly reported in last 7 days',
#        'Deaths - newly reported in last 7 days per 100000 population',
#        'Deaths - newly reported in last 24 hours'],
#       dtype='object')

# %%
df2.isnull().sum()
# Out:
# Name                                                            0
# WHO Region                                                      0
# Cases - cumulative total                                        0
# Cases - cumulative total per 100000 population                  0
# Cases - newly reported in last 7 days                           0
# Cases - newly reported in last 7 days per 100000 population     0
# Cases - newly reported in last 24 hours                         0
# Deaths - cumulative total                                       0
# Deaths - cumulative total per 100000 population                 0
# Deaths - newly reported in last 7 days                          0
# Deaths - newly reported in last 7 days per 100000 population    0
# Deaths - newly reported in last 24 hours                        0
# dtype: int64

# %%
df2.describe()
# Out:
#        Cases - cumulative total  \
# count              5.600000e+01
# mean               1.391149e+06
# std                5.379878e+06
# min                8.000000e+00
# 25%                2.438750e+03
# 50%                2.072550e+04
# 75%                3.891705e+05
# max                3.512523e+07
#
#        Cases - cumulative total per 100000 population  \
# count                                       56.000000
# mean                                      4609.253929
# std                                       3621.482992
# min                                        119.100000
# 25%                                       1491.317500
# 50%                                       3765.015000
# 75%                                       7441.595000
# max                                      13505.310000
#
#        Cases - newly reported in last 7 days  \
# count                              56.000000
# mean                            23568.553571
# ...

# %%
df2.loc[ 1:]
# Out:
#                                   Name WHO Region  Cases - cumulative total  \
# 1                               Brazil   Americas                  19985817
# 2                            Argentina   Americas                   4961880
# 3                             Colombia   Americas                   4807979
# 4                               Mexico   Americas                   2880409
# 5                                 Peru   Americas                   2116652
# 6                                Chile   Americas                   1619183
# 7                               Canada   Americas                   1433775
# 8                              Ecuador   Americas                    489089
# 9     Bolivia (Plurinational State of)   Americas                    475265
# 10                            Paraguay   Americas                    453367
# 11                              Panama   Americas                    437744
# ...

# %%
#Randomly select a single row: df = df2.sample()

# %%
#Randomly select a single row:

# %%
df2 = df2.sample()

# %%
df2
# Out:
#                          Name WHO Region  Cases - cumulative total  \
# 52  Saint Pierre and Miquelon   Americas                        28
#
#     Cases - cumulative total per 100000 population  \
# 52                                          483.18
#
#     Cases - newly reported in last 7 days  \
# 52                                      0
#
#     Cases - newly reported in last 7 days per 100000 population  \
# 52                                                0.0
#
#     Cases - newly reported in last 24 hours  Deaths - cumulative total  \
# 52                                        0                          0
#
#     Deaths - cumulative total per 100000 population  \
# 52                                              0.0
#
#     Deaths - newly reported in last 7 days  \
# 52                                       0
#
#     Deaths - newly reported in last 7 days per 100000 population  \
# 52                                                0.0
#
# ...

# %%
#Allow a random selection of the same row more than once 
#(by setting replace=True): df = df.sample(n=3,replace=True)

# %%
df2 = df2.sample(n=1)

# %%
print(df2)
# Out:
#                          Name WHO Region  Cases - cumulative total  \
# 52  Saint Pierre and Miquelon   Americas                        28
#
#     Cases - cumulative total per 100000 population  \
# 52                                          483.18
#
#     Cases - newly reported in last 7 days  \
# 52                                      0
#
#     Cases - newly reported in last 7 days per 100000 population  \
# 52                                                0.0
#
#     Cases - newly reported in last 24 hours  Deaths - cumulative total  \
# 52                                        0                          0
#
#     Deaths - cumulative total per 100000 population  \
# 52                                              0.0
#
#     Deaths - newly reported in last 7 days  \
# 52                                       0
#
#     Deaths - newly reported in last 7 days per 100000 population  \
# 52                                                0.0
#
# ...

# %%
# let us Randomly select a specified number of rows. For example, to select 1 random row, set n=1:

# %%
df2
# Out:
#                          Name WHO Region  Cases - cumulative total  \
# 52  Saint Pierre and Miquelon   Americas                        28
#
#     Cases - cumulative total per 100000 population  \
# 52                                          483.18
#
#     Cases - newly reported in last 7 days  \
# 52                                      0
#
#     Cases - newly reported in last 7 days per 100000 population  \
# 52                                                0.0
#
#     Cases - newly reported in last 24 hours  Deaths - cumulative total  \
# 52                                        0                          0
#
#     Deaths - cumulative total per 100000 population  \
# 52                                              0.0
#
#     Deaths - newly reported in last 7 days  \
# 52                                       0
#
#     Deaths - newly reported in last 7 days per 100000 population  \
# 52                                                0.0
#
# ...

# %%
# Above are the cases reported in Saint Pierre and Miquelon , Americas

# %%
#Outlier Detection and Treatment
#Outlier Detection
#Outliers are extrem values that deviate from other observations on data, they may indicate a variability in a measurement,
#experimental errors or a novelty.

#Boxplots are a great way of detecting outliers. Once the outliers have been detected, 
#they can be imputed with the 5th and 95th percentilles.

# %%
import seaborn as sns

# %%
# Outlier detection using boxplots
plt.figure(figsize= (20,15))
plt.subplot(4,4,1)
sns.boxplot(df2['WHO Region'])

plt.subplot(4,4,2)
sns.boxplot(df2['Cases - cumulative total'])

plt.subplot(4,4,3)
sns.boxplot(df2['Cases - cumulative total per 100000 population'])

plt.subplot(4,4,4)
sns.boxplot(df2['Cases - newly reported in last 7 days'])

plt.subplot(4,4,5)
sns.boxplot(df2['Cases - newly reported in last 7 days per 100000 population'])

plt.subplot(4,4,6)
sns.boxplot(df2['Cases - newly reported in last 24 hours'])

plt.subplot(4,4,7)
sns.boxplot(df2['Deaths - cumulative total'])

plt.subplot(4,4,8)
sns.boxplot(df2['Deaths - cumulative total per 100000 population'])

plt.subplot(4,4,9)
sns.boxplot(df2['Deaths - newly reported in last 7 days'])

plt.subplot(4,4,10)
sns.boxplot(df2['Deaths - newly reported in last 7 days per 100000 population'])

plt.subplot(4,4,11)
sns.boxplot(df2['Deaths - newly reported in last 24 hours'])
# Out:
# C:\Users\D1 TELECOM LTD\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-ce94a903abbf> in <module>
#       2 plt.figure(figsize= (20,15))
#       3 plt.subplot(4,4,1)
# ----> 4 sns.boxplot(df2['WHO Region'])
#       5
#       6 plt.subplot(4,4,2)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
# Boxplots are a standardized way of displaying the distribution of data based on a five number summary (“minimum”, first quartile (Q1),
#median, third quartile (Q3), and “maximum”).
#   median (Q2/50th Percentile): the middle value of the dataset.
#   first quartile (Q1/25th Percentile): the middle number between the smallest number (not the “minimum”) and the median of the dataset.
#   third quartile (Q3/75th Percentile): the middle value between the median and the highest value (not the “maximum”) of the dataset.
#   interquartile range (IQR): 25th to the 75th percentile.
#   whiskers (shown in blue)
#   outliers (shown as green circles)
#“maximum”: Q3 + 1.5*IQR
#“minimum”: Q1 -1.5*IQR

# %%
#Apart from 'Deaths newly reported in last 24 hours' all the other attributes shownpresence of outliers. These lower level and upper level outliers will be replaced by the 5th and 95th percentile respectively.

# %%
#Use pandas. Series. corr() to find the correlation between two columns

# %%
print(df2)
# Out:
#                          Name WHO Region  Cases - cumulative total  \
# 52  Saint Pierre and Miquelon   Americas                        28
#
#     Cases - cumulative total per 100000 population  \
# 52                                          483.18
#
#     Cases - newly reported in last 7 days  \
# 52                                      0
#
#     Cases - newly reported in last 7 days per 100000 population  \
# 52                                                0.0
#
#     Cases - newly reported in last 24 hours  Deaths - cumulative total  \
# 52                                        0                          0
#
#     Deaths - cumulative total per 100000 population  \
# 52                                              0.0
#
#     Deaths - newly reported in last 7 days  \
# 52                                       0
#
#     Deaths - newly reported in last 7 days per 100000 population  \
# 52                                                0.0
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

plt.figure(figsize=(20,10))
df2["WHO Region"].value_counts().plot.pie(autopct='%1.1f%%',)
# Out:
# <AxesSubplot:ylabel='WHO Region'>

# %%
df2.groupby(["WHO Region"])["Cases - cumulative total","Deaths - cumulative total"].max()
# Out:
# <ipython-input-70-6c5c6f3e531b>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df2.groupby(["WHO Region"])["Cases - cumulative total","Deaths - cumulative total"].max()
#             Cases - cumulative total  Deaths - cumulative total
# WHO Region
# Americas                    35125227                     609613

# %%
#using linear regression model to predict
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
# linear regression model using the Cases feature and caculate the R^2 for Deaths 
#sns.regplot(x="Cases", y="Deaths", data=df2)
#plt.ylim(0, )
X = df2[['Cases - cumulative total']]
Y = df2['Deaths - cumulative total']
lm = LinearRegression()
lm
lm.fit(X,Y)
lm.score(X, Y)
# Out:
# 0.8792308876889582

# %%
#How  identified cases help us predict deaths 
X = df2[['Cases - cumulative total']]
Y = df2['Deaths - cumulative total']
lm = LinearRegression()
lm
lm.fit(X,Y)
Yhat=lm.predict(X)
Yhat[0:5]
# Out:
# array([717033.41254925, 411426.6486584 , 108150.84283307, 105044.17047466,
#         66133.90713725])

# %%
lm.intercept_
# Out:
# 7989.469991278296

# %%
lm.coef_
# Out:
# array([0.02018617])

# %%
#Yhat = a + b X
Yhat = 79890+0.02018*0.8792
#79,890.0177

# %%
#total cumulative cases  in the last 14 days feature and caculate the R^2 for Deaths
X = df2[['Cases - cumulative total']]
Y = df2['Deaths - cumulative total']
lm1 = LinearRegression()
lm1
lm1.fit(X,Y)
Yhat=lm.predict(X)
lm1.score(X, Y)
# Out:
# 0.8792308876889582

# %%
#Cases - cumulative total_fit
lm.fit(X, Y)
# Find the R^2
print('The R-square is: ', lm.score(X, Y))
# Out:
# The R-square is:  0.8792308876889582

# %%
Yhat=lm.predict(X)
print('The output of the first four predicted value is: ', Yhat[0:4])
# Out:
# The output of the first four predicted value is:  [717033.41254925 411426.6486584  108150.84283307 105044.17047466]

# %%
#data visualization


import seaborn as sns
import matplotlib.pyplot as plt 

sns.scatterplot(x = "Cases - cumulative total", y = "Deaths - cumulative total", data = df2 )
plt.xlabel("Cases - cumulative total")
plt.ylabel("Deaths - cumulative total")
plt.title("Cases - cumulative total vs Deaths - cumulative total")
plt.show()

# %%
from sklearn.metrics import mean_squared_error

from sklearn.metrics import mean_absolute_error

# %%
mse = mean_squared_error(df2['Deaths - cumulative total'], Yhat)
print('The mean square error of price and predicted value is: ', mse)
# Out:
# The mean square error of price and predicted value is:  1591037749.0452864

# %%
 #  Mean Absolute Error or MAE
#We know that an error basically is the absolute difference between the actual or true values and the values that are predicted. Absolute difference means that if the result has a negative sign, it is ignored.

#Hence, MAE = True values – Predicted values

#MAE takes the average of this error from every sample in a dataset and gives the output.

#This can be implemented using sklearn’s mean_absolute_error method:

mae = mean_absolute_error(df2['Deaths - cumulative total'], Yhat)

print('The mean absolute error of price and predicted value is: ', mae)
# Out:
# The mean absolute error of price and predicted value is:  17830.683595439605

# %%
#Let's develop a model using these variables as the predictor variables
Z = df2[['Cases - cumulative total', 'Deaths - newly reported in last 7 days']]

# %%
lm.fit(Z, df2['Deaths - cumulative total'])
# Out:
# LinearRegression()

# %%
lm.intercept_
# Out:
# 1087.9224360504231

# %%
lm.coef_
# Out:
# array([1.33050586e-02, 4.60334041e+01])

# %%
# fit the model 
lm.fit(Z, df2['Deaths - cumulative total'])
# Find the R^2
print('The R-square is: ', lm.score(Z, df2['Deaths - cumulative total']))
# Out:
# The R-square is:  0.9571986831591526

# %%
Y_predict_multifit = lm.predict(Z)

# %%
print('The mean square error of price and predicted value using multifit is: ', \
      mean_squared_error(df2['Deaths - cumulative total'], Y_predict_multifit))
# Out:
# The mean square error of price and predicted value using multifit is:  563873572.4681641

# %%
#Use pandas. Series. corr() to find the correlation between two columns

# %%
print(df2)
# Out:
#                                   Name WHO Region  Cases - cumulative total  \
# 0             United States of America   Americas                  35125227
# 1                               Brazil   Americas                  19985817
# 2                            Argentina   Americas                   4961880
# 3                             Colombia   Americas                   4807979
# 4                               Mexico   Americas                   2880409
# 5                                 Peru   Americas                   2116652
# 6                                Chile   Americas                   1619183
# 7                               Canada   Americas                   1433775
# 8                              Ecuador   Americas                    489089
# 9     Bolivia (Plurinational State of)   Americas                    475265
# 10                            Paraguay   Americas                    453367
# ...

# %%
correlation_df2 = df2.corr()

# %%
print(correlation_df2)
# Out:
#                                                     Cases - cumulative total  \
# Cases - cumulative total                                                 NaN
# Cases - cumulative total per 100000 population                           NaN
# Cases - newly reported in last 7 days                                    NaN
# Cases - newly reported in last 7 days per 10000...                       NaN
# Cases - newly reported in last 24 hours                                  NaN
# Deaths - cumulative total                                                NaN
# Deaths - cumulative total per 100000 population                          NaN
# Deaths - newly reported in last 7 days                                   NaN
# Deaths - newly reported in last 7 days per 1000...                       NaN
# Deaths - newly reported in last 24 hours                                 NaN
#
#                                                     Cases - cumulative total per 100000 population  \
# ...

# %%
# lets us find the correlation among
# find columns using pearson method
df2.corr(method ='pearson')
# Out:
#                                                     Cases - cumulative total  \
# Cases - cumulative total                                                 NaN
# Cases - cumulative total per 100000 population                           NaN
# Cases - newly reported in last 7 days                                    NaN
# Cases - newly reported in last 7 days per 10000...                       NaN
# Cases - newly reported in last 24 hours                                  NaN
# Deaths - cumulative total                                                NaN
# Deaths - cumulative total per 100000 population                          NaN
# Deaths - newly reported in last 7 days                                   NaN
# Deaths - newly reported in last 7 days per 1000...                       NaN
# Deaths - newly reported in last 24 hours                                 NaN
#
#                                                     Cases - cumulative total per 100000 population  \
# ...

# %%
df2.head(10)
# Out:
#                          Name WHO Region  Cases - cumulative total  \
# 52  Saint Pierre and Miquelon   Americas                        28
#
#     Cases - cumulative total per 100000 population  \
# 52                                          483.18
#
#     Cases - newly reported in last 7 days  \
# 52                                      0
#
#     Cases - newly reported in last 7 days per 100000 population  \
# 52                                                0.0
#
#     Cases - newly reported in last 24 hours  Deaths - cumulative total  \
# 52                                        0                          0
#
#     Deaths - cumulative total per 100000 population  \
# 52                                              0.0
#
#     Deaths - newly reported in last 7 days  \
# 52                                       0
#
#     Deaths - newly reported in last 7 days per 100000 population  \
# 52                                                0.0
#
# ...

# %%
# To find the correlation among
# the columns using kendall method
df2.corr(method ='kendall')
# Out:
#                                                     Cases - cumulative total  \
# Cases - cumulative total                                                 1.0
# Cases - cumulative total per 100000 population                           NaN
# Cases - newly reported in last 7 days                                    NaN
# Cases - newly reported in last 7 days per 10000...                       NaN
# Cases - newly reported in last 24 hours                                  NaN
# Deaths - cumulative total                                                NaN
# Deaths - cumulative total per 100000 population                          NaN
# Deaths - newly reported in last 7 days                                   NaN
# Deaths - newly reported in last 7 days per 1000...                       NaN
# Deaths - newly reported in last 24 hours                                 NaN
#
#                                                     Cases - cumulative total per 100000 population  \
# ...

# %%
df2
# Out:
#                          Name WHO Region  Cases - cumulative total  \
# 52  Saint Pierre and Miquelon   Americas                        28
#
#     Cases - cumulative total per 100000 population  \
# 52                                          483.18
#
#     Cases - newly reported in last 7 days  \
# 52                                      0
#
#     Cases - newly reported in last 7 days per 100000 population  \
# 52                                                0.0
#
#     Cases - newly reported in last 24 hours  Deaths - cumulative total  \
# 52                                        0                          0
#
#     Deaths - cumulative total per 100000 population  \
# 52                                              0.0
#
#     Deaths - newly reported in last 7 days  \
# 52                                       0
#
#     Deaths - newly reported in last 7 days per 100000 population  \
# 52                                                0.0
#
# ...

# %%
#df2 = np.corrcoef(x, y)

# %%
import numpy as np
import scipy.stats
x = np.arange(10, 20)
y = np.array([2, 1, 4, 5, 8, 12, 18, 25, 96, 48])
scipy.stats.pearsonr(x, y)    # Pearson's r
# Out:
# (0.7586402890911869, 0.010964341301680832)

# %%
#Use Pandas Correlation Matrix
   #Correlations

# %%
corr = df2.corr()

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.heatmap(corr, cmap="Greens",annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,8))
sns.heatmap(corr, cmap="Greens")
# Out:
# <AxesSubplot:>

# %%
#Degree of correlation:
#Perfect:
#If the value is near ± 1, then it said to be a perfect correlation: as one variable increases, 
#the other variable tends to also increase (if positive) or decrease (if negative).
#High degree: 
 #If the coefficient value lies between ± 0.50 and ± 1, then it is said to be a strong correlation.

# %%
# In case you need to print the values of correlation matrix in the descending order. 
#use sort_values() to do that as shown below.

# %%
c1 = corr.abs().unstack()
c1.sort_values(ascending = False)
# Out:
# Cases - cumulative total                  Cases - cumulative total                                       NaN
#                                           Cases - cumulative total per 100000 population                 NaN
#                                           Cases - newly reported in last 7 days                          NaN
#                                           Cases - newly reported in last 7 days per 100000 population    NaN
#                                           Cases - newly reported in last 24 hours                        NaN
#                                                                                                           ..
# Deaths - newly reported in last 24 hours  Deaths - cumulative total                                      NaN
#                                           Deaths - cumulative total per 100000 population                NaN
#                                           Deaths - newly reported in last 7 days                         NaN
# ...

# %%
corr[corr < 1].unstack().transpose()\
    .sort_values( ascending=False)\
    .drop_duplicates()
# Out:
# Cases - newly reported in last 24 hours                       Cases - newly reported in last 7 days                           0.996674
# Deaths - newly reported in last 24 hours                      Deaths - newly reported in last 7 days                          0.992107
# Cases - newly reported in last 7 days                         Cases - cumulative total                                        0.976097
# Cases - cumulative total                                      Cases - newly reported in last 24 hours                         0.960186
#                                                               Deaths - cumulative total                                       0.937673
# Deaths - newly reported in last 24 hours                      Deaths - cumulative total                                       0.895919
# Deaths - newly reported in last 7 days                        Deaths - cumulative total                                       0.889871
# ...

# %%
#Descriptive Statistics
Descriptive statistics are measures that summarize important features of data, often with a single number. 
Producing descriptive statistics is a common first step to take after cleaning and preparing a data set for analysis.

# %%
df2.mean()
# Out:
# Cases - cumulative total                                         28.00
# Cases - cumulative total per 100000 population                  483.18
# Cases - newly reported in last 7 days                             0.00
# Cases - newly reported in last 7 days per 100000 population       0.00
# Cases - newly reported in last 24 hours                           0.00
# Deaths - cumulative total                                         0.00
# Deaths - cumulative total per 100000 population                   0.00
# Deaths - newly reported in last 7 days                            0.00
# Deaths - newly reported in last 7 days per 100000 population      0.00
# Deaths - newly reported in last 24 hours                          0.00
# dtype: float64

# %%
df2.median()
# Out:
# Cases - cumulative total                                         28.00
# Cases - cumulative total per 100000 population                  483.18
# Cases - newly reported in last 7 days                             0.00
# Cases - newly reported in last 7 days per 100000 population       0.00
# Cases - newly reported in last 24 hours                           0.00
# Deaths - cumulative total                                         0.00
# Deaths - cumulative total per 100000 population                   0.00
# Deaths - newly reported in last 7 days                            0.00
# Deaths - newly reported in last 7 days per 100000 population      0.00
# Deaths - newly reported in last 24 hours                          0.00
# dtype: float64

# %%
# Get the mean of each row
df2.mean(axis=1)
# Out:
# 52    51.118
# dtype: float64

# %%
import math
import statistics
import numpy as np
import scipy.stats
import pandas as pd

# %%
 np.random.seed(seed=0)
 x = np.random.randn(1000)
 y = np.random.randn(100)
 z = np.random.randn(10)

# %%
# Make sure figures appear inline in Ipython Notebook
# %matplotlib inline
# Create a quick bar chart
df2.plot(kind='bar');

# %%
# Import all libraries for this portion of the blog post
from scipy.integrate import quad
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
x = np.linspace(-4, 4, num = 100)
constant = 1.0 / np.sqrt(2*np.pi)
pdf_normal_distribution = constant * np.exp((-x**2) / 2.0)
fig, ax = plt.subplots(figsize=(10, 5));
ax.plot(x, pdf_normal_distribution);
ax.set_ylim(0);
ax.set_title('Normal Distribution', size = 20);
ax.set_ylabel('Probability Density', size = 20);
ax.set_xlabel('Saint Pierre and Miquelon', size = 20);

# %%
# The graph above does not show you the probability of events but their probability density. 
# To get the probability of an event within a given range we will need to integrate. 
# Suppose we are interested in finding the probability of a random data point landing within the interquartile range .6745 standard deviation of the mean, 
#we need to integrate from -.6745 to .6745. This can be done with SciPy.

# %%
# Here are some of the properties of normal distribution of the population:

The points in the normal distribution are symmetric. Normal distribution can not be used to model skewed distributions.
The mean, median and mode of normal distribution are equal.
Half of the population is less than the mean and half is greater than the mean.
The empirical rule of the normal distribution goes like the following: 68% of the observations fall within +/- 1 standard deviation from the mean, 95% of the observations fall within +/- 2 standard deviation from the mean and 99.7% of the observations fall within +/- 3 standard deviation from the mean.

# %%
# Make PDF for the normal distribution a function
def normalProbabilityDensity(x):
    constant = 1.0 / np.sqrt(2*np.pi)
    return(constant * np.exp((-x**2) / 2.0) )
# Integrate PDF from -.6745 to .6745
result_50p, _ = quad(normalProbabilityDensity, -.6745, .6745, limit = 1000)
print(result_50p)
# Out:
# 0.5000065142726018

# %%
# Make a PDF for the normal distribution a function
def normalProbabilityDensity(x):
    constant = 1.0 / np.sqrt(2*np.pi)
    return(constant * np.exp((-x**2) / 2.0) )
# Integrate PDF from -2.698 to 2.698
result_99_3p, _ = quad(normalProbabilityDensity,
                     -2.698,
                     2.698,
                     limit = 1000)
print(result_99_3p)
# Out:
# 0.9930242559336101

# %%
#      Predict With Classification Models

# %%
# example of training a final classification model
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_blobs
# generate 2d classification dataset
X, y = make_blobs(n_samples=100, centers=2, n_features=2, random_state=1)
# fit final model
model = LogisticRegression()
model.fit(X, y)
# Out:
# LogisticRegression()

# %%
# example of training a final classification model
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_blobs
# generate 2d classification dataset
X, y = make_blobs(n_samples=100, centers=2, n_features=2, random_state=1)
# fit final model
model = LogisticRegression()
model.fit(X, y)
# new instances where we do not know the answer
Xnew, _ = make_blobs(n_samples=3, centers=2, n_features=2, random_state=1)
# make a prediction
ynew = model.predict(Xnew)
# show the inputs and predicted outputs
for i in range(len(Xnew)):
	print("X=%s, Predicted=%s" % (Xnew[i], ynew[i]))
# Out:
# X=[-0.79415228  2.10495117], Predicted=0
# X=[-8.25290074 -4.71455545], Predicted=1
# X=[-2.18773166  3.33352125], Predicted=0

# %%
# Running the example predicts the class for the three new data instances, then prints the data and the predictions together.

# %%
#  Single Class Prediction
#If you had just one new data instance, you can provide this as instance wrapped in an array to the predict() function; for example:

# %%
# example of making a single class prediction
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_blobs
# generate 2d classification dataset
X, y = make_blobs(n_samples=100, centers=2, n_features=2, random_state=1)
# fit final model
model = LogisticRegression()
model.fit(X, y)
# define one new instance
Xnew = [[-0.79415228, 2.10495117]]
# make a prediction
ynew = model.predict(Xnew)
print("X=%s, Predicted=%s" % (Xnew[0], ynew[0]))
# Out:
# X=[-0.79415228, 2.10495117], Predicted=0

# %%
# Below is an example of a finalized LinearRegression model. 
#Again, the functions demonstrated for making regression predictions apply to all of the regression models available in scikit-learn.

# %%
# example of training a final regression model
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression
# generate regression dataset
X, y = make_regression(n_samples=100, n_features=2, noise=0.1, random_state=1)
# fit final model
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# example of making multiple probability predictions
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_blobs
# generate 2d classification dataset
X, y = make_blobs(n_samples=100, centers=2, n_features=2, random_state=1)
# fit final model
model = LogisticRegression()
model.fit(X, y)
# new instances where we do not know the answer
Xnew, _ = make_blobs(n_samples=3, centers=2, n_features=2, random_state=1)
# make a prediction
ynew = model.predict_proba(Xnew)
# show the inputs and predicted probabilities
for i in range(len(Xnew)):
	print("X=%s, Predicted=%s" % (Xnew[i], ynew[i]))
# Out:
# X=[-0.79415228  2.10495117], Predicted=[0.99467199 0.00532801]
# X=[-8.25290074 -4.71455545], Predicted=[0.00223842 0.99776158]
# X=[-2.18773166  3.33352125], Predicted=[0.99389073 0.00610927]

# %%
# example of training a final regression model
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression
# generate regression dataset
X, y = make_regression(n_samples=100, n_features=2, noise=0.1)
# fit final model
model = LinearRegression()
model.fit(X, y)
# new instances where we do not know the answer
Xnew, _ = make_regression(n_samples=3, n_features=2, noise=0.1, random_state=1)
# make a prediction
ynew = model.predict(Xnew)
# show the inputs and predicted outputs
for i in range(len(Xnew)):
	print("X=%s, Predicted=%s" % (Xnew[i], ynew[i]))
# Out:
# X=[-1.07296862 -0.52817175], Predicted=-96.4801372168042
# X=[-0.61175641  1.62434536], Predicted=-15.254377253347187
# X=[-2.3015387   0.86540763], Predicted=-165.70562326162315

# %%
# Running the example makes multiple predictions, then prints the inputs and predictions side-by-side for review.

# %%
# Single Regression Prediction
# The same function can be used to make a prediction for a single data instance as long as it is suitably wrapped in a surrounding list or array.

#For example:
# example of training a final regression model
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression
# generate regression dataset
X, y = make_regression(n_samples=100, n_features=2, noise=0.1)
# fit final model
model = LinearRegression()
model.fit(X, y)
# define one new data instance
Xnew = [[-1.07296862, -0.52817175]]
# make a prediction
ynew = model.predict(Xnew)
# show the inputs and predicted outputs
print("X=%s, Predicted=%s" % (Xnew[0], ynew[0]))
# Out:
# X=[-1.07296862, -0.52817175], Predicted=-90.33702674527474

# %%
# lets check RMSE
#Here N is the total number of observations/rows in the dataset. The sigma symbol denotes that the difference between actual and predicted values taken on every i value ranging from 1 to n.

#This can be implemented using sklearn's mean_squared_error method:

# %%
# let us find the linear regression
#Multiple Linear Regression Model

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
# Any results you write to the current directory are saved as output.

import os
print(os.listdir)
# Out:
# <built-in function listdir>

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random

# %%
#Fitting the model
#Fitting the linear regression model parameters with the training set

# %%
df2.describe()
# Out:
#        Cases - cumulative total  \
# count              5.600000e+01
# mean               1.391149e+06
# std                5.379878e+06
# min                8.000000e+00
# 25%                2.438750e+03
# 50%                2.072550e+04
# 75%                3.891705e+05
# max                3.512523e+07
#
#        Cases - cumulative total per 100000 population  \
# count                                       56.000000
# mean                                      4609.253929
# std                                       3621.482992
# min                                        119.100000
# 25%                                       1491.317500
# 50%                                       3765.015000
# 75%                                       7441.595000
# max                                      13505.310000
#
#        Cases - newly reported in last 7 days  \
# count                              56.000000
# mean                            23568.553571
# ...

# %%
#The describe() method is used for calculating some statistical data like percentile, 
#mean and std of the numerical values of the Series or DataFrame. 
#It analyzes both numeric and object series and also the DataFrame column sets of mixed data types.

# %%
# let us use iloc
#When using .loc, or .iloc, you can control the output format by passing lists or single values to the selectors.

# %%
X = df2.iloc[:, :-1].values
y = df2.iloc[:, 1].values

# %%
print(x,y)
# Out:
# [-4.         -3.91919192 -3.83838384 -3.75757576 -3.67676768 -3.5959596
#  -3.51515152 -3.43434343 -3.35353535 -3.27272727 -3.19191919 -3.11111111
#  -3.03030303 -2.94949495 -2.86868687 -2.78787879 -2.70707071 -2.62626263
#  -2.54545455 -2.46464646 -2.38383838 -2.3030303  -2.22222222 -2.14141414
#  -2.06060606 -1.97979798 -1.8989899  -1.81818182 -1.73737374 -1.65656566
#  -1.57575758 -1.49494949 -1.41414141 -1.33333333 -1.25252525 -1.17171717
#  -1.09090909 -1.01010101 -0.92929293 -0.84848485 -0.76767677 -0.68686869
#  -0.60606061 -0.52525253 -0.44444444 -0.36363636 -0.28282828 -0.2020202
#  -0.12121212 -0.04040404  0.04040404  0.12121212  0.2020202   0.28282828
#   0.36363636  0.44444444  0.52525253  0.60606061  0.68686869  0.76767677
#   0.84848485  0.92929293  1.01010101  1.09090909  1.17171717  1.25252525
#   1.33333333  1.41414141  1.49494949  1.57575758  1.65656566  1.73737374
#   1.81818182  1.8989899   1.97979798  2.06060606  2.14141414  2.22222222
# ...

# %%
x
# Out:
# array([-4.        , -3.91919192, -3.83838384, -3.75757576, -3.67676768,
#        -3.5959596 , -3.51515152, -3.43434343, -3.35353535, -3.27272727,
#        -3.19191919, -3.11111111, -3.03030303, -2.94949495, -2.86868687,
#        -2.78787879, -2.70707071, -2.62626263, -2.54545455, -2.46464646,
#        -2.38383838, -2.3030303 , -2.22222222, -2.14141414, -2.06060606,
#        -1.97979798, -1.8989899 , -1.81818182, -1.73737374, -1.65656566,
#        -1.57575758, -1.49494949, -1.41414141, -1.33333333, -1.25252525,
#        -1.17171717, -1.09090909, -1.01010101, -0.92929293, -0.84848485,
#        -0.76767677, -0.68686869, -0.60606061, -0.52525253, -0.44444444,
#        -0.36363636, -0.28282828, -0.2020202 , -0.12121212, -0.04040404,
#         0.04040404,  0.12121212,  0.2020202 ,  0.28282828,  0.36363636,
#         0.44444444,  0.52525253,  0.60606061,  0.68686869,  0.76767677,
#         0.84848485,  0.92929293,  1.01010101,  1.09090909,  1.17171717,
# ...

# %%
y
# Out:
# array([  12.70288344,   19.71297996,  137.63054845,  122.04324687,
#          -7.07562905,  106.79770544,    6.10155046,  -63.14846183,
#          93.55447567, -233.60616381,  -68.30387174,   87.81895404,
#           4.68029718, -108.57723128,   97.99974835, -124.46211658,
#         160.29768026,  250.85313936,  -46.53239915,   53.42344967,
#           4.17328682,   -7.93549464,   33.97559998, -113.5028189 ,
#        -232.64929777,  -14.40678363,  -49.23815546,   -8.06912984,
#         171.51086548,   83.02454875,   37.33959262,   34.91623158,
#         119.85122089, -159.58838807, -148.97930497,   41.7205676 ,
#         -49.4853411 ,   32.92037131,   57.97259787,   -1.57254082,
#        -192.85449283,  -27.5690415 ,    8.95147867,   29.31162667,
#         -32.97925386,   74.69996627,  -43.28963716,  124.33279492,
#          75.81884913,  -32.8797741 ,   34.67491169,  137.23582334,
#         205.58258879,   -1.84826216,   81.04650995, -169.09613258,
# ...

# %%
X = df2.iloc[:, :-1].values
y = df2.iloc[:, 4].values

# %%
x
# Out:
# array([-4.        , -3.91919192, -3.83838384, -3.75757576, -3.67676768,
#        -3.5959596 , -3.51515152, -3.43434343, -3.35353535, -3.27272727,
#        -3.19191919, -3.11111111, -3.03030303, -2.94949495, -2.86868687,
#        -2.78787879, -2.70707071, -2.62626263, -2.54545455, -2.46464646,
#        -2.38383838, -2.3030303 , -2.22222222, -2.14141414, -2.06060606,
#        -1.97979798, -1.8989899 , -1.81818182, -1.73737374, -1.65656566,
#        -1.57575758, -1.49494949, -1.41414141, -1.33333333, -1.25252525,
#        -1.17171717, -1.09090909, -1.01010101, -0.92929293, -0.84848485,
#        -0.76767677, -0.68686869, -0.60606061, -0.52525253, -0.44444444,
#        -0.36363636, -0.28282828, -0.2020202 , -0.12121212, -0.04040404,
#         0.04040404,  0.12121212,  0.2020202 ,  0.28282828,  0.36363636,
#         0.44444444,  0.52525253,  0.60606061,  0.68686869,  0.76767677,
#         0.84848485,  0.92929293,  1.01010101,  1.09090909,  1.17171717,
# ...

# %%
# let check for Mean Squared Error, Mean Absolute Error, Root Mean Squared Error and R Squared

# %%
from sklearn.metrics import mean_squared_error

actual_values = [3, -0.5, 2, 7]
predicted_values = [2.5, 0.0, 2, 8]

mean_squared_error(actual_values, predicted_values)
# Out:
# 0.375

# %%
 #  Mean Absolute Error or MAE
#We know that an error basically is the absolute difference between the actual or true values and the values that are predicted. Absolute difference means that if the result has a negative sign, it is ignored.

#Hence, MAE = True values – Predicted values

#MAE takes the average of this error from every sample in a dataset and gives the output.

#This can be implemented using sklearn’s mean_absolute_error method:

# %%
df2.shape
# Out:
# (1, 12)

# %%
df2.loc()

# %%
import numpy as np
from sklearn.model_selection import cross_val_score
from sklearn import datasets, svm

X, y = datasets.load_digits(return_X_y=True)

svc = svm.SVC(kernel='linear')
C_s = np.logspace(-10, 0, 10)

scores = list()

# %%
df2
# Out:
#                          Name WHO Region  Cases - cumulative total  \
# 52  Saint Pierre and Miquelon   Americas                        28
#
#     Cases - cumulative total per 100000 population  \
# 52                                          483.18
#
#     Cases - newly reported in last 7 days  \
# 52                                      0
#
#     Cases - newly reported in last 7 days per 100000 population  \
# 52                                                0.0
#
#     Cases - newly reported in last 24 hours  Deaths - cumulative total  \
# 52                                        0                          0
#
#     Deaths - cumulative total per 100000 population  \
# 52                                              0.0
#
#     Deaths - newly reported in last 7 days  \
# 52                                       0
#
#     Deaths - newly reported in last 7 days per 100000 population  \
# 52                                                0.0
#
# ...

# %%
# Polynomial Regression
def polyfit(x, y, degree):
    results = {}

    coeffs = numpy.polyfit(x, y, degree)
     # Polynomial Coefficients
    results['polynomial'] = coeffs.tolist()

    correlation = numpy.corrcoef(x, y)[0,1]

     # r
    results['correlation'] = correlation
     # r-squared
    results['determination'] = correlation**2

    return results

# %%
# Polynomial Regression
def polyfit(x, y, degree):
    results = {}

    coeffs = numpy.polyfit(x, y, degree)

     # Polynomial Coefficients
    results['polynomial'] = coeffs.tolist()

    # r-squared
    p = numpy.poly1d(coeffs)
    # fit values, and mean
    yhat = p(x)                         # or [p(z) for z in x]
    ybar = numpy.sum(y)/len(y)          # or sum(y)/len(y)
    ssreg = numpy.sum((yhat-ybar)**2)   # or sum([ (yihat - ybar)**2 for yihat in yhat])
    sstot = numpy.sum((y - ybar)**2)    # or sum([ (yi - ybar)**2 for yi in y])
    results['determination'] = ssreg / sstot

    return results

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

# Construct the columns for the different powers of x
def get_r2_statsmodels(x, y, k=1):
    xpoly = np.column_stack([x**i for i in range(k+1)])    
    return sm.OLS(y, xpoly).fit().rsquared

# Use the formula API and construct a formula describing the polynomial
def get_r2_statsmodels_formula(x, y, k=1):
    formula = 'y ~ 1 + ' + ' + '.join('I(x**{})'.format(i) for i in range(1, k+1))
    data = {'x': x, 'y': y}
    return smf.ols(formula, data).fit().rsquared # or rsquared_adj

# %%
def get_r2_numpy_corrcoef(x, y):
    return np.corrcoef(x, y)[0, 1]**2

# %%
import numpy as np
from scipy import stats
import statsmodels.api as sm
import math

# %%
n=1000
x = np.random.rand(1000)*10
x.sort()
y = 10 * x + (5+np.random.randn(1000)*10-5)

x_list = list(x)
y_list = list(y)

# %%
def get_r2_numpy(x, y):
    slope, intercept = np.polyfit(x, y, 1)
    r_squared = 1 - (sum((y - (slope * x + intercept))**2) / ((len(y) - 1) * np.var(y, ddof=1)))
    return r_squared

# %%
def get_r2_scipy(x, y):
    _, _, r_value, _, _ = stats.linregress(x, y)
    return r_value**2

# %%
def get_r2_statsmodels(x, y):
    return sm.OLS(y, sm.add_constant(x)).fit().rsquared

# %%
def get_r2_python(x_list, y_list):
    n = len(x_list)
    x_bar = sum(x_list)/n
    y_bar = sum(y_list)/n
    x_std = math.sqrt(sum([(xi-x_bar)**2 for xi in x_list])/(n-1))
    y_std = math.sqrt(sum([(yi-y_bar)**2 for yi in y_list])/(n-1))
    zx = [(xi-x_bar)/x_std for xi in x_list]
    zy = [(yi-y_bar)/y_std for yi in y_list]
    r = sum(zxi*zyi for zxi, zyi in zip(zx, zy))/(n-1)
    return r**2

# %%
def get_r2_numpy_manual(x, y):
    zx = (x-np.mean(x))/np.std(x, ddof=1)
    zy = (y-np.mean(y))/np.std(y, ddof=1)
    r = np.sum(zx*zy)/(len(x)-1)
    return r**2

# %%
def get_r2_numpy_corrcoef(x, y):
    return np.corrcoef(x, y)[0, 1]**2

# %%
print('Python')
# %timeit get_r2_python(x_list, y_list)
print('Numpy polyfit')
# %timeit get_r2_numpy(x, y)
print('Numpy Manual')
# %timeit get_r2_numpy_manual(x, y)
print('Numpy corrcoef')
# %timeit get_r2_numpy_corrcoef(x, y)
print('Scipy')
# %timeit get_r2_scipy(x, y)
print('Statsmodels')
# %timeit get_r2_statsmodels(x, y)
# Out:
# Python
# 3.3 ms ± 80.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Numpy polyfit
# 626 µs ± 122 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# Numpy Manual
# 129 µs ± 12.1 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# Numpy corrcoef
# 190 µs ± 16.5 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# Scipy
# 513 µs ± 70.3 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# Statsmodels
# 833 µs ± 88.9 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
#RMSE:
#It stands for Root Mean Square Error.  It equates to the square root of the squares of the sum of differences between each observed data value and the predicted value. The minimum value of the RMSE is the best for the best fit line. 
#Basically, it is the square root of variance.

# %%
# import all necessery libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,PolynomialFeatures
# %matplotlib inline

# %%
# %%capture
! pip install seaborn

# %%
#Implementing Linear Regression In Python - Step by Step Guide

# %%
#I have taken a dataset that contains a total of four variables but we are going to work on two variables. 
#I will apply the regression based on the mathematics of the Regression.

# %%
# plot the data point

# %%
#x-axis label

# %%
#y-axis label
plt.ylabel('head')
# Out:
# Text(0, 0.5, 'head')

# %%
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#From the above figure, we have to recall the assumptions of linear regression
 #(data should be linear scattered) and this can be seen in the graph.

#Now let's work on the RMSEE values and try to find the best fit line.

# %%
# Now we have to find the accuracy that will show whether our model is good or not.
#In the next cell, we just call linear regression from the Sklearn library. And try to make a model name "regressor". In the next line, 
#we have applied regressor.fit because this is our trained dataset.
# Now, let’s check the accuracy of the model with this dataset.
#Again, I tried to check the regression line in our dataset.

# %%
#lets use a decision tree
#A decision tree is a flowchart-like tree structure where an internal node represents feature(or attribute),
#the branch represents a decision rule, and each leaf node represents the outcome.
#The topmost node in a decision tree is known as the root node. 
#It learns to partition on the basis of the attribute value.
# Visualizing the Decision Tree

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.datasets import load_breast_cancer
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
from sklearn import tree

# %%
# Load libraries
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
# Visualizing the Decision Tree

# %%
# Step 1: Import the model you want to use
# This was already imported earlier in the notebook so commenting out
#from sklearn.tree import DecisionTreeClassifier
# Step 2: Make an instance of the Model
dataset = DecisionTreeClassifier(max_depth = 2, 
                             random_state = 0)
# Step 3: Train the model on the data

# Step 4: Predict labels of unseen (test) data
# Not doing this step in the tutorial
# clf.predict(dataset_test)

# %%
print(dataset)
# Out:
# DecisionTreeClassifier(max_depth=2, random_state=0)

# %%
from matplotlib import pyplot as plt
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier 
from sklearn import tree

# %%
# Prepare the data data
iris = datasets.load_iris()
X = iris.data
y = iris.target

# %%
# Fit the classifier with default hyper-parameters
clf = DecisionTreeClassifier(random_state=1234)
model = clf.fit(X, y)

# %%
dataset = tree.export_text(clf)
print(dataset)
# Out:
# |--- feature_2 <= 2.45
# |   |--- class: 0
# |--- feature_2 >  2.45
# |   |--- feature_3 <= 1.75
# |   |   |--- feature_2 <= 4.95
# |   |   |   |--- feature_3 <= 1.65
# |   |   |   |   |--- class: 1
# |   |   |   |--- feature_3 >  1.65
# |   |   |   |   |--- class: 2
# |   |   |--- feature_2 >  4.95
# |   |   |   |--- feature_3 <= 1.55
# |   |   |   |   |--- class: 2
# |   |   |   |--- feature_3 >  1.55
# |   |   |   |   |--- feature_0 <= 6.95
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_0 >  6.95
# |   |   |   |   |   |--- class: 2
# |   |--- feature_3 >  1.75
# |   |   |--- feature_2 <= 4.85
# |   |   |   |--- feature_1 <= 3.10
# |   |   |   |   |--- class: 2
# |   |   |   |--- feature_1 >  3.10
# |   |   |   |   |--- class: 1
# |   |   |--- feature_2 >  4.85
# |   |   |   |--- class: 2

# %%
# If you want to save it to the file, it can be done with following code:

# %%
#with open("decistion_tree.log", "w") as fout:
    #fout.write(text_representation)

# %%
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(clf, 
                   feature_names=iris.feature_names,  
                   class_names=iris.target_names,
                   filled=True)

# %%
fig.savefig("decistion_tree.png")

# %%
import graphviz
# DOT data
dot_data = tree.export_graphviz(clf, out_file=None, 
                                feature_names=iris.feature_names,  
                                class_names=iris.target_names,
                                filled=True)

# Draw graph
graph = graphviz.Source(dot_data, format="png") 
graph
# Out:
# 'C:\Users\D1' is not recognized as an internal or external command,
# operable program or batch file.
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~\anaconda3\lib\site-packages\graphviz\files.py in _repr_svg_(self)
#     111
#     112     def _repr_svg_(self):
# --> 113         return self.pipe(format='svg').decode(self._encoding)
#     114
#     115     def pipe(self, format=None, renderer=None, formatter=None, quiet=False):
#
# ~\anaconda3\lib\site-packages\graphviz\files.py in pipe(self, format, renderer, formatter, quiet)
# ...

# %%
import six
import sys
sys.modules['sklearn.externals.six'] = six
from six import StringIO

# %%
from sklearn.externals.six import StringIO
import pydotplus
import matplotlib.image as mpimg
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier

# %%
#Build an empty DecisionTree object with depth 5x = rnd.standard_normal(100)

# %%
CovidTree = DecisionTreeClassifier(criterion="entropy", max_depth = 5)
CovidTree # it shows the default parameters
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5)

# %%
DecisionTreeClassifier(criterion='entropy', max_depth=5)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5)

# %%
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler 
from sklearn.preprocessing import Binarizer
from sklearn.preprocessing import StandardScaler 
#X= preprocessing.StandardScaler().fit(X).transform(X)
#X[0:5]

# %%
# Train the decision tree using the global X data set.

# %%
DecisionTreeClassifier(criterion='entropy', max_depth=5)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5)

# %%
from sklearn.datasets import load_iris
from sklearn import tree
clf = tree.DecisionTreeClassifier()
iris = load_iris()
clf = clf.fit(iris.data, iris.target)
tree.export_graphviz(clf, out_file='tree.dot')

# %%
#Evaluating the Accuracy of Decison Tree Algorithm
#Use Decision Tree object previously trained.

# %%
#printDecisionTree

# %%
# demonstration of calculating metrics for a neural network model using sklearn
from sklearn.datasets import make_circles
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix

# %%
! pip install keras

# %%
! pip install tensorflow
import tensorflow

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
# generate and prepare the dataset
def get_data():
	# generate dataset
	X, y = make_circles(n_samples=1000, noise=0.1, random_state=1)
	# split into train and test
	n_test = 500
	trainX, testX = X[:n_test, :], X[n_test:, :]
	trainy, testy = y[:n_test], y[n_test:]
	return trainX, trainy, testX, testy

# %%
# define and fit the model
def get_model(trainX, trainy):
	# define model
	model = Sequential()
	model.add(Dense(100, input_dim=2, activation='relu'))
	model.add(Dense(1, activation='sigmoid'))
	# compile model
	model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
	# fit model
	model.fit(trainX, trainy, epochs=300, verbose=0)
	return model

# %%
# generate data
trainX, trainy, testX, testy = get_data()
# fit model
model = get_model(trainX, trainy)

# %%
# predict probabilities for test set
yhat_probs = model.predict(testX, verbose=0)
# predict crisp classes for test set
yhat_classes = model.predict(testX, verbose=0)
#[[0.893292]]
# reduce to 1d array
yhat_probs = yhat_probs[:, 0]
yhat_classes = yhat_classes[:, 0]

# %%
from sklearn.datasets import make_circles
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from keras.models import Sequential
from keras.layers import Dense

# %%
# split into train and test
trainX, testX = X[:n_test, :], X[n_test:, :]
trainy, testy = y[:n_test], y[n_test:]

# %%
# accuracy: (tp + tn) / (p + n)
#accuracy = accuracy_score(testy, yhat_classes)
#print('Accuracy: %f' % accuracy)
# precision tp / (tp + fp)
#precision = precision_score(testy, yhat_classes)
#print('Precision: %f' % precision)
# recall: tp / (tp + fn)
#recall = recall_score(testy, yhat_classes)
#print('Recall: %f' % recall)
# f1: 2 tp / (2 tp + fp + fn)
#f1 = f1_score(testy, yhat_classes)
#print('F1 score: %f' % f1)

# %%
# F1 score - F1 Score is the weighted average of Precision and Recall. 
#Therefore, this score takes both false positives and false negatives into account. 
#Intuitively it is not as easy to understand as accuracy, but F1 is usually more useful than accuracy,
# especially if you have an uneven class distribution.

# %%
# That is, a good F1 score means that you have low false positives and low false negatives,
 #so you're correctly identifying real threats and you are not disturbed by false alarms. 
 #An F1 score is considered perfect when it's 1 , while the model is a total failure when it's 0 .

# %%
# Accuracy works best if false positives and false negatives have similar cost. 
#If the cost of false positives and false negatives are very different, 
#it’s better to look at both Precision and Recall. In our case, F1 score is 0.854291.

# %%
# kappa
#kappa = cohen_kappa_score(testy, yhat_classes)
#print('Cohens kappa: %f' % kappa)
# ROC AUC
#auc = roc_auc_score(testy, yhat_probs)
#print('ROC AUC: %f' % auc)
# confusion matrix
#matrix = confusion_matrix(testy, yhat_classes)
#print(matrix)
